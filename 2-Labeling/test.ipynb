# %%
import pandas as pd

# %%
temp = pd.read_csv("temp.csv")
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   createdAtBlockNumber    10 non-null     int64
#  1   createdAtTimestamp      10 non-null     object
#  2   id                      10 non-null     object
#  3   reserve0                10 non-null     float64
#  4   reserve1                10 non-null     float64
#  5   reserveETH              10 non-null     float64
#  6   reserveUSD              10 non-null     float64
#  7   totalSupply             10 non-null     float64
#  8   txCount                 10 non-null     int64
#  9   reserve00               10 non-null     float64
#  10  reserve11               10 non-null     float64
#  11  token0.id               10 non-null     object
#  12  token0.name             10 non-null     object
#  13  token0.symbol           10 non-null     object
# ...

# %%
label = pd.read_csv("Labeling_v3.csv")
label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23245 entries, 0 to 23244
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   createdAtTimestamp          23245 non-null  object
#  1   id                          23245 non-null  object
#  2   token0.name                 23242 non-null  object
#  3   token0.symbol               23244 non-null  object
#  4   token1.name                 23245 non-null  object
#  5   token1.symbol               23245 non-null  object
#  6   token00.id                  23245 non-null  object
#  7   token00.name                23242 non-null  object
#  8   token00.symbol              23244 non-null  object
#  9   token00.txCount             23245 non-null  int64
#  10  token00_creator_address     23245 non-null  object
#  11  txCount                     23245 non-null  int64
#  12  initial_Liquidity_Token     23245 non-null  float64
# ...

# %%
result = pd.read_csv("main_pair.csv")

# %%
zero = result.iloc[:100]

# %%
zero.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   createdAtBlockNumber    100 non-null    int64
#  1   createdAtTimestamp      100 non-null    object
#  2   id                      100 non-null    object
#  3   reserve0                100 non-null    float64
#  4   reserve1                100 non-null    float64
#  5   reserveETH              100 non-null    float64
#  6   reserveUSD              100 non-null    float64
#  7   totalSupply             100 non-null    float64
#  8   txCount                 100 non-null    int64
#  9   reserve00               100 non-null    float64
#  10  reserve11               100 non-null    float64
#  11  token0.id               100 non-null    object
#  12  token0.name             100 non-null    object
#  13  token0.symbol           100 non-null    object
# ...

# %%
zero.to_csv("zero.csv")

# %%
result[['initial_Liquidity_Token', 'swapIn']]
# Out:
#    initial_Liquidity_Token  swapIn
# 0             5.520000e+10      77
# 1             6.594900e+10     197
# 2             4.722222e+08      14
# 3             5.589000e+11      27
# 4             3.239313e+14       5
# 5             9.700000e+08      50
# 6             5.589000e+11      27
# 7             1.283362e+07      44
# 8             7.200000e+08      11
# 9             1.091558e+08     513

# %%
result['initial_Liquidity_Token'].dtype
# Out:
# dtype('float64')

# %%
result.head()
# Out:
#    createdAtBlockNumber createdAtTimestamp  \
# 0              20006562           2024-6-2
# 1              20006549           2024-6-2
# 2              20006534           2024-6-2
# 3              20006517           2024-6-2
# 4              20006509           2024-6-2
#
#                                            id      reserve0   reserve1  \
# 0  0x95b8f454dca6342bac578be5a0e91e48c930b4d3  0.000000e+00   0.000000
# 1  0xa23cec0fe0a81b9b568ff9f94685cfea8c19ce23  3.499220e+10  28.443805
# 2  0xc5494572bb74b5dc10e02cbcd5601dc8c529184b  3.982222e+08   1.186498
# 3  0x1408516701d1d3dec4c1461c19512b2ae7438cea  2.937388e+11   1.907053
# 4  0x42994ff44febb45e896aa1b6c00b0d44501a077a  3.029052e+14   1.069629
#
#    reserveETH     reserveUSD    totalSupply  txCount     reserve00  ...  \
# 0    0.000000       0.000000       0.000000        0  0.000000e+00  ...
# 1   56.887611  214682.565207  994602.935849      307  3.499220e+10  ...
# ...

# %%
label.tail()
# Out:
#       createdAtTimestamp                                          id  \
# 23240         2020-05-19  0x0d4a11d5eeaac28ec3f61d100daf4d40471f1852
# 23241         2020-05-18  0x302ac87b1b5ef18485971ed0115a17403ea30911
# 23242         2020-05-18  0xbb2b8038a1640196fbe3e38816f3e67cba72d940
# 23243         2020-05-05  0xb4e16d0168e52d35cacd2c6185b44281ec28c9dc
# 23244         2020-12-22  0x21b8065d10f73ee2e260e5b47d3344d3ced7596e
#
#          token0.name token0.symbol    token1.name token1.symbol  \
# 23240  Wrapped Ether          WETH     Tether USD          USDT
# 23241      Flexacoin           FXC  Wrapped Ether          WETH
# 23242    Wrapped BTC          WBTC  Wrapped Ether          WETH
# 23243         USD//C          USDC  Wrapped Ether          WETH
# 23244     Wise Token          WISE  Wrapped Ether          WETH
#
#                                        token00.id token00.name token00.symbol  \
# 23240  0xdac17f958d2ee523a2206206994597c13d831ec7   Tether USD           USDT
# ...

# %%
import os

# %%
os.cpu_count()
# Out:
# 12
